# %% [markdown]
# Finally, do the same with 1000 two-dimensional random data points from a distribution of your choice
# (e.g., bivariate Gaussian distribution). Here, you could generate many more classes (or consider that
# a single class is made up of multiple blobs). Again, apply k-means for various values of k. Plot the
# final clustering to see what happened. See whether the results make sense given how you generated
# the data.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

#for KMeans
from sklearn.cluster import KMeans
import numpy as np

# %%
mu, sigma = 100, 30 # mean and standard deviation
X = (np.random.normal(mu, sigma, 1000))
Y= (np.random.normal(mu, sigma*2/3, 1000))
A= np.linspace(X, Y, 2)
A=A.transpose()

# %%
plt.scatter(A[:,0], A[:,1], s=20);
plt.xlim(1, 200)
plt.ylim(1, 200)
# Out:
# (1, 200)

# %%
kmeans = KMeans(n_clusters=2)
kmeans.fit(A)
y_kmeans = kmeans.predict(A)

plt.scatter(A[:,0], A[:,1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(A)
y_kmeans = kmeans.predict(A)

plt.scatter(A[:,0], A[:,1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(A)
y_kmeans = kmeans.predict(A)

plt.scatter(A[:,0], A[:,1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
kmeans = KMeans(n_clusters=5)
kmeans.fit(A)
y_kmeans = kmeans.predict(A)

plt.scatter(A[:,0], A[:,1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
